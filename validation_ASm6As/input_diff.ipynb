# %%
os.chdir("/Charles/project/ASm6A/data/validation_ASm6A/LBFC20201232/")
df = pd.read_table("test.txt")
df.head()
# Out:
#     chr      start        end REF ALT   ...    input_REF_count  input_ALT_count  odds_ratio        pvalue  V_mark
# 0  chr8  144732449  144732450   G   A   ...                321              404    1.723502  3.820000e-09     ref
# 1  chr7   17833343   17833344   T   C   ...                199              256    0.427847  1.790000e-10     alt
# 2  chr4  183812286  183812287   A   G   ...                122               71    2.497609  6.943480e-04     ref
# 3  chr9   21862270   21862271   A   C   ...                 44              170    3.556777  2.240000e-12     ref
# 4  chr3  186793728  186793729   A   G   ...                705              449    1.827829  3.420000e-13     ref
#
# [5 rows x 12 columns]

# %%
###
df_1 = df[df['input_REF_count'] > df['input_ALT_count']]
df_1['diff_prop'] = (df_1['input_REF_count']-df_1['input_ALT_count']) / df_1['input_ALT_count']
df_1['sig_diff'] = np.where(df_1['diff_prop']>0.3, "yes", "no")
df_1_yes = df_1[df_1['sig_diff'] == "yes"]
### ip have the same trend as input
df_1_yes_yes = df_1_yes[df_1_yes['IP_REF_count'] > df_1_yes['IP_ALT_count']]
print(len(df_1), len(df_1_yes), len(df_1_yes_yes))
##
df_2 = df[df['input_REF_count'] <= df['input_ALT_count']]
df_2['diff_prop'] = (df_2['input_ALT_count']-df_2['input_REF_count']) / df_2['input_REF_count']
df_2['sig_diff'] = np.where(df_2['diff_prop']>0.3, "yes", "no")
df_2_yes = df_2[df_2['sig_diff'] == "yes"]
df_2_yes_yes = df_2_yes[df_2_yes['IP_REF_count'] <= df_2_yes['IP_ALT_count']]
print(len(df_2), len(df_2_yes), len(df_2_yes_yes))
#### combine
df_combine = pd.concat([df_1, df_2])
# Out:
# 21 14 12
# 22 10 8
# /home/galaxy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/galaxy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/galaxy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# ...
